# %%
# %reload_ext watermark

# %%
# %watermark -a "Samantha Zeitlin" -d -u -p ipython,pandas,seaborn
# Out:
# Samantha Zeitlin
# Last updated: 02/10/2015
#
# ipython 2.3.1
# pandas 0.15.2
# seaborn 0.5.1

# %%
import numpy as np
import pandasql
import pandas
from datetime import datetime, date, time
from dateutil.parser import parse
import pytz
from delta_range import delta_range
from hour_lookup import centering, dict_grower, hour_lookup

import matplotlib.pyplot as plt
import matplotlib 
import seaborn as sns

# %matplotlib inline

# %%
df = pandas.read_csv("sorted_by_date.csv", index_col=0)

# %%
df.head()
# Out:
#                 StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 161  2013-01-02T15:51:51Z           1690.76        14632.39         12.05
# 51   2013-01-03T00:20:26Z           1928.39        15305.22         12.34
# 375  2013-01-04T15:46:52Z           1680.40        14651.60         12.28
# 330  2013-01-04T23:59:27Z           1962.15        15237.36         11.43
# 191  2013-01-07T15:56:14Z           1657.51        14625.53         12.02
#
#      Calories  AverageSpeed
# 161       572          8.65
# 51        702          7.94
# 375       572          8.72
# 330       691          7.77
# 191       609          8.82

# %%
df.shape
# Out:
# (414, 6)

# %%
type(df['StartTime'][0])
# Out:
# str

# %%
#ideas: could just take times, ignore days (not sure how many will be identical, probably not many)
#could convert times back & use a bag-of-words approach to count occurrences(for that could maybe do hours +/-1)
df['parsed']=[parse(x) for x in df['StartTime']]

# %%
df['parsed'].head()
# Out:
# 161    2013-01-02 15:51:51+00:00
# 51     2013-01-03 00:20:26+00:00
# 375    2013-01-04 15:46:52+00:00
# 330    2013-01-04 23:59:27+00:00
# 191    2013-01-07 15:56:14+00:00
# Name: parsed, dtype: object

# %%
df['zoned'] = [x.astimezone(pytz.timezone('US/Pacific')) for x in df['parsed']]

# %%
df['zoned'].head()
# Out:
# 161    2013-01-02 07:51:51-08:00
# 51     2013-01-02 16:20:26-08:00
# 375    2013-01-04 07:46:52-08:00
# 330    2013-01-04 15:59:27-08:00
# 191    2013-01-07 07:56:14-08:00
# Name: zoned, dtype: object

# %%
df['hour']=[x.hour for x in df['zoned']]

# %%
df['hour'].head()
# Out:
# 161     7
# 51     16
# 375     7
# 330    15
# 191     7
# Name: hour, dtype: int64

# %%
df.head()
# Out:
#                 StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 161  2013-01-02T15:51:51Z           1690.76        14632.39         12.05
# 51   2013-01-03T00:20:26Z           1928.39        15305.22         12.34
# 375  2013-01-04T15:46:52Z           1680.40        14651.60         12.28
# 330  2013-01-04T23:59:27Z           1962.15        15237.36         11.43
# 191  2013-01-07T15:56:14Z           1657.51        14625.53         12.02
#
#      Calories  AverageSpeed                     parsed  \
# 161       572          8.65  2013-01-02 15:51:51+00:00
# 51        702          7.94  2013-01-03 00:20:26+00:00
# 375       572          8.72  2013-01-04 15:46:52+00:00
# 330       691          7.77  2013-01-04 23:59:27+00:00
# 191       609          8.82  2013-01-07 15:56:14+00:00
#
#                          zoned  hour
# 161  2013-01-02 07:51:51-08:00     7
# 51   2013-01-02 16:20:26-08:00    16
# 375  2013-01-04 07:46:52-08:00     7
# 330  2013-01-04 15:59:27-08:00    15
# 191  2013-01-07 07:56:14-08:00     7

# %%
#want to know the variation of hours to know how to set the delta_range for what to include, probably easiest to plot & look  
df['hour'].std()
# Out:
# 4.8422640150721108

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np

sns.set_palette("deep", desat=0.6)
sns.set_context(rc={"figure.figsize": (8,4)})

# %matplotlib inline

# %%
df['hour'].hist() #note that these are not normal distributions, so not well suited for machine learning 
plt.xlabel('hour of the day(correct timezone)')
plt.ylabel('frequency')

# %%
#convert distances to miles 
df['Miles'] = df['DistanceMeters']/1609.34

#convert times to minutes (better for comparisons) and hours (better for speed calculations)
df['Minutes'] = df['TotalTimeSeconds']/60
df['Trip_hours'] = df['Minutes']/60

#convert speeds to miles per hour
df['average_mph'] = df['Miles']/df['Trip_hours']
df['maximum_mph'] = df['MaximumSpeed']*3600/1609.34

# %%
df.head()
# Out:
#                 StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 161  2013-01-02T15:51:51Z           1690.76        14632.39         12.05
# 51   2013-01-03T00:20:26Z           1928.39        15305.22         12.34
# 375  2013-01-04T15:46:52Z           1680.40        14651.60         12.28
# 330  2013-01-04T23:59:27Z           1962.15        15237.36         11.43
# 191  2013-01-07T15:56:14Z           1657.51        14625.53         12.02
#
#      Calories  AverageSpeed                     parsed  \
# 161       572          8.65  2013-01-02 15:51:51+00:00
# 51        702          7.94  2013-01-03 00:20:26+00:00
# 375       572          8.72  2013-01-04 15:46:52+00:00
# 330       691          7.77  2013-01-04 23:59:27+00:00
# 191       609          8.82  2013-01-07 15:56:14+00:00
#
#                          zoned  hour     Miles    Minutes  Trip_hours  \
# 161  2013-01-02 07:51:51-08:00     7  9.092168  28.179333    0.469656
# 51   2013-01-02 16:20:26-08:00    16  9.510246  32.139833    0.535664
# 375  2013-01-04 07:46:52-08:00     7  9.104105  28.006667    0.466778
# 330  2013-01-04 15:59:27-08:00    15  9.468080  32.702500    0.545042
# 191  2013-01-07 07:56:14-08:00     7  9.087906  27.625167    0.460419
#
#      average_mph  maximum_mph
# 161    19.359226    26.955149
# 51     17.754130    27.603862
# 375    19.504152    27.469646
# 330    17.371296    25.568245
# 191    19.738318    26.888041

# %%
#actually just want to add a column with a flag for daytime category, and sort by that. Or, could sort by hours... 
sorted_by_hours= df.sort_index(by='hour')

# %%
sorted_by_hours.head()
# Out:
#                 StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 406  2013-07-30T13:37:41Z            574.61         4607.00         12.69
# 121  2013-05-01T13:51:33Z           1592.60        14634.20         13.48
# 120  2013-05-01T13:43:58Z            433.59         3190.36         10.91
# 147  2013-10-21T13:41:57Z            695.13         4779.31         12.56
# 67   2013-10-23T13:38:01Z            647.00         4788.20         12.30
#
#      Calories  AverageSpeed                     parsed  \
# 406       184          8.02  2013-07-30 13:37:41+00:00
# 121       596          9.19  2013-05-01 13:51:33+00:00
# 120       171          7.36  2013-05-01 13:43:58+00:00
# 147       147          6.88  2013-10-21 13:41:57+00:00
# 67        181          7.40  2013-10-23 13:38:01+00:00
#
#                          zoned  hour     Miles    Minutes  Trip_hours  \
# 406  2013-07-30 06:37:41-07:00     6  2.862664   9.576833    0.159614
# 121  2013-05-01 06:51:33-07:00     6  9.093293  26.543333    0.442389
# 120  2013-05-01 06:43:58-07:00     6  1.982403   7.226500    0.120442
# 147  2013-10-21 06:41:57-07:00     6  2.969733  11.585500    0.193092
# 67   2013-10-23 06:38:01-07:00     6  2.975257  10.783333    0.179722
#
#      average_mph  maximum_mph
# 406    17.934932    28.386792
# 121    20.554976    30.153976
# 120    16.459443    24.405036
# 147    15.379912    28.095990
# 67     16.554753    27.514385

# %%
sorted_by_time_and_date = df.sort_index(by = ['hour', 'zoned'])

# %%
sorted_by_time_and_date.head()
# Out:
#                 StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 66   2013-02-27T14:47:54Z           2084.49        17797.09         13.30
# 74   2013-03-22T13:46:00Z           2086.73        17819.94         12.26
# 230  2013-04-09T13:44:35Z           3548.92        29733.52         13.88
# 120  2013-05-01T13:43:58Z            433.59         3190.36         10.91
# 121  2013-05-01T13:51:33Z           1592.60        14634.20         13.48
#
#      Calories  AverageSpeed                     parsed  \
# 66        720          8.54  2013-02-27 14:47:54+00:00
# 74        714          8.54  2013-03-22 13:46:00+00:00
# 230      1195          8.38  2013-04-09 13:44:35+00:00
# 120       171          7.36  2013-05-01 13:43:58+00:00
# 121       596          9.19  2013-05-01 13:51:33+00:00
#
#                          zoned  hour      Miles    Minutes  Trip_hours  \
# 66   2013-02-27 06:47:54-08:00     6  11.058627  34.741500    0.579025
# 74   2013-03-22 06:46:00-07:00     6  11.072825  34.778833    0.579647
# 230  2013-04-09 06:44:35-07:00     6  18.475599  59.148667    0.985811
# 120  2013-05-01 06:43:58-07:00     6   1.982403   7.226500    0.120442
# 121  2013-05-01 06:51:33-07:00     6   9.093293  26.543333    0.442389
#
#      average_mph  maximum_mph
# 66     19.098703    29.751327
# 74     19.102696    27.424907
# 230    18.741520    31.048753
# 120    16.459443    24.405036
# 121    20.554976    30.153976

# %%
speed_filter_left = sorted_by_time_and_date[sorted_by_time_and_date['average_mph'] <= 40.0]

# %%
speed_filter_right=speed_filter_left[speed_filter_left['average_mph']>=5.0]

# %%
filtered=speed_filter_right.reset_index()

# %%
sns.distplot(filtered['average_mph'])

# %%
sns.set(style="ticks")
sns.jointplot("hour", "average_mph", data=filtered)

# %%
#want to flag hours to use later as categorical colors on plots 
def leg_definer(hour):
    """Helper function to identify trip legs by hour, i.e.
    6 AM: first leg (to Caltrain) - morning_city
    7 AM: second leg (to Oracle) - morning_suburb
    4 PM (16): 3rd leg (return to Caltrain) - evening_suburb
    5 PM (17): 4th leg (return home) - evening_city
    other hour: other
    
    >>> leg_definer(6):
    'morning_city'
    
    (int) -> (str)
    """
    legref = {6:"morning_city", 7:"morning_suburb", 8: "morning_suburb", 13: "other", 14: "other", 16:"evening_suburb", 17:"evening_city", 9:"other", 11:"other", 12:"other", 15:"evening_suburb", 18:"evening_later"}
    return legref[hour]

# %%
filtered['leg_flag']=[leg_definer(hour) for hour in filtered['hour']]

# %%
filtered['zoned'] = filtered['zoned'].apply(pandas.to_datetime)

# %%
filtered['month'] = [item.month for item in filtered['StartTime']]

# %%
filtered['day'] = [item.day for item in filtered['zoned']]

# %%
g = sns.lmplot("day", "average_mph", filtered, hue="leg_flag", fit_reg=False)
g.set(xticks=[0,5,10,15,20,25,30], ylim=(5,24))

# %%
#really want to group by month and plot that way, or by day of the week, and compare those
filtered['weekday']=[item.weekday() for item in filtered['zoned']]

# %%
filtered.head()
# Out:
#    index           StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 0     66 2013-02-27 14:47:54           2084.49        17797.09         13.30
# 1     74 2013-03-22 13:46:00           2086.73        17819.94         12.26
# 2    230 2013-04-09 13:44:35           3548.92        29733.52         13.88
# 3    120 2013-05-01 13:43:58            433.59         3190.36         10.91
# 4    121 2013-05-01 13:51:33           1592.60        14634.20         13.48
#
#    Calories  AverageSpeed                     parsed  \
# 0       720          8.54  2013-02-27 14:47:54+00:00
# 1       714          8.54  2013-03-22 13:46:00+00:00
# 2      1195          8.38  2013-04-09 13:44:35+00:00
# 3       171          7.36  2013-05-01 13:43:58+00:00
# 4       596          9.19  2013-05-01 13:51:33+00:00
#
#                        zoned  hour      Miles    Minutes  Trip_hours  \
# 0  2013-02-27 06:47:54-08:00     6  11.058627  34.741500    0.579025
# 1  2013-03-22 06:46:00-07:00     6  11.072825  34.778833    0.579647
# 2  2013-04-09 06:44:35-07:00     6  18.475599  59.148667    0.985811
# 3  2013-05-01 06:43:58-07:00     6   1.982403   7.226500    0.120442
# 4  2013-05-01 06:51:33-07:00     6   9.093293  26.543333    0.442389
#
#    average_mph  maximum_mph      leg_flag  month  day  weekday
# 0    19.098703    29.751327  morning_city      2   27        2
# 1    19.102696    27.424907  morning_city      3   22        4
# 2    18.741520    31.048753  morning_city      4    9        1
# 3    16.459443    24.405036  morning_city      5    1        2
# 4    20.554976    30.153976  morning_city      5    1        2

# %%
sns.set_context("talk")
g=sns.lmplot("weekday", "average_mph", filtered, hue="leg_flag", x_jitter=0.15, fit_reg=False)
g.set(xlim=(-1,6), ylim=(5,24))

# %%
f, ax= plt.subplots()
sns.violinplot(filtered['average_mph'], filtered['weekday'])

# %%
filtered.to_csv("zoned_flagged_filtered_2013.csv")

# %%
morning_suburb= filtered[filtered['leg_flag']=='morning_suburb']

# %%
morning_suburb.weekday.value_counts()
# Out:
# 1    31
# 2    30
# 0    28
# 4    25
# 3     5
# dtype: int64

# %%
#try this to be able to add titles
from matplotlib.font_manager import FontProperties
from pylab import *

# %%
f, ax= plt.subplots()
g = sns.violinplot(morning_suburb['average_mph'], morning_suburb['weekday'])
title('Morning Suburb')
sns.despine()
#g.set(ylim=(5,30))

# %%
evening_suburb=filtered[filtered['leg_flag']=='evening_suburb']

# %%
evening_suburb.weekday.value_counts()
# Out:
# 1    35
# 2    27
# 0    25
# 4    22
# 3    16
# 5     6
# 6     1
# dtype: int64

# %%
evening_suburb.head()
# Out:
#      index           StartTime  TotalTimeSeconds  DistanceMeters  \
# 209    330 2013-01-04 23:59:27           1962.15        15237.36
# 210     49 2013-01-11 23:56:46           2359.68        17255.28
# 211    279 2013-02-26 23:57:57           1755.68        14137.46
# 212    338 2013-04-24 22:17:51           2234.69        15840.44
# 213      4 2013-05-03 22:59:16           2209.53        17216.25
#
#      MaximumSpeed  Calories  AverageSpeed                     parsed  \
# 209         11.43       691          7.77  2013-01-04 23:59:27+00:00
# 210         13.34       664          7.31  2013-01-11 23:56:46+00:00
# 211         11.73       507          8.05  2013-02-26 23:57:57+00:00
# 212         18.69       615          7.09  2013-04-24 22:17:51+00:00
# 213         10.99       678          7.79  2013-05-03 22:59:16+00:00
#
#                          zoned  hour      Miles    Minutes  Trip_hours  \
# 209  2013-01-04 15:59:27-08:00    15   9.468080  32.702500    0.545042
# 210  2013-01-11 15:56:46-08:00    15  10.721961  39.328000    0.655467
# 211  2013-02-26 15:57:57-08:00    15   8.784632  29.261333    0.487689
# 212  2013-04-24 15:17:51-07:00    15   9.842818  37.244833    0.620747
# 213  2013-05-03 15:59:16-07:00    15  10.697708  36.825500    0.613758
#
#      average_mph  maximum_mph        leg_flag  month  day  weekday
# 209    17.371296    25.568245  evening_suburb      1    4        4
# 210    16.357751    29.840804  evening_suburb      1   11        4
# 211    18.012779    26.239328  evening_suburb      2   26        1
# 212    15.856402    41.808443  evening_suburb      4   24        2
# 213    17.429838    24.583991  evening_suburb      5    3        4

# %%
evening_suburb.to_csv("evening_suburb_2013.csv", index_col=0)
morning_suburb.to_csv("morning_suburb_2013.csv", index_col=0)

# %%
f, ax= plt.subplots()
g = sns.violinplot(evening_suburb['average_mph'], evening_suburb['weekday'])
g.set(ylim=(10,24))
title('Evening Suburb')
sns.despine()

# %%
f, ax= plt.subplots()
g = sns.violinplot(evening_suburb['average_mph'], evening_suburb['weekday'], color="Blues")#, alpha=0.7)
g = sns.violinplot(morning_suburb['average_mph'], morning_suburb['weekday'], color="Yellow")# alpha=0.3)
g.set(ylim=(10,24))
title('Morning(yellow) vs. Evening(blue) Suburb')
sns.despine()

# %%
filtered.set_index(['StartTime'], inplace=True)

# %%
filtered.head()
# Out:
#    index           StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 0    397 2014-01-02 14:44:27            615.57         4734.30         12.89
# 1    362 2014-01-03 14:37:08            605.17         4735.76         12.94
# 2    450 2014-01-06 14:37:04            606.17         4724.96         12.23
# 3    517 2014-01-07 14:42:00            603.10         4710.42         12.13
# 4     27 2014-01-08 14:37:12            663.73         4760.85         11.00
#
#    Calories  AverageSpeed                     parsed  \
# 0       209          7.69  2014-01-02 14:44:27+00:00
# 1       174          7.83  2014-01-03 14:37:08+00:00
# 2       182          7.79  2014-01-06 14:37:04+00:00
# 3       207          7.81  2014-01-07 14:42:00+00:00
# 4       167          7.17  2014-01-08 14:37:12+00:00
#
#                        zoned  hour     Miles    Minutes  Trip_hours  \
# 0  2014-01-02 06:44:27-08:00     6  2.941765  10.259500    0.170992
# 1  2014-01-03 06:37:08-08:00     6  2.942672  10.086167    0.168103
# 2  2014-01-06 06:37:04-08:00     6  2.935961  10.102833    0.168381
# 3  2014-01-07 06:42:00-08:00     6  2.926927  10.051667    0.167528
# 4  2014-01-08 06:37:12-08:00     6  2.958262  11.062167    0.184369
#
#    average_mph  maximum_mph      leg_flag  month  day
# 0    17.204142    28.834180  morning_city      1    2
# 1    17.505196    28.946028  morning_city      1    3
# 2    17.436463    27.357799  morning_city      1    6
# 3    17.471291    27.134105  morning_city      1    7
# 4    16.045296    24.606360  morning_city      1    8

# %%
days = filtered.resample('B')

# %%
# %install_ext https://raw.githubusercontent.com/szeitlin/watermark/master/watermark.py
# Out:
# Installed watermark.py. To use it, type:
#   %load_ext watermark

# %%
#previous year (matplotlib)
fig, axes=plt.subplots(nrows=2, ncols=3)

set_time['Calories'].plot(kind='bar', ax=axes[0,0]); axes[0,0].set_title('Calories')
set_time['maximum_mph'].plot(kind='bar', ax=axes[0,1]); axes[0,1].set_title('max speed(mph)')
set_time['average_mph'].plot(kind='bar', ax=axes[0,2]); axes[0,2].set_title('avg speed(mph)')
set_time['Miles'].plot(kind='bar', ax=axes[1,0]); axes[1,0].set_title('Miles')
set_time['Minutes'].plot(kind='bar', ax=axes[1,1]); axes[1,1].set_title('Minutes')
plt.tight_layout() #required to keep x-axis labels & titles from overlapping

# %%
#not sure what group by is doing here- is that the average, the max, some random number-?
