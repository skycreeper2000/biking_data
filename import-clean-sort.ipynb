# %%
import pandas

# %%
raw = pandas.read_csv("All Training Center Data.csv")

# %%
raw.head()
# Out:
#   RecID" MultiSportSessionRecID NextSportRecID             StartTime   Sport  \
# 0      2                    NaN            NaN  2012-11-28T00:15:52Z  Biking
# 1      3                    NaN            NaN  2012-08-20T23:15:15Z  Biking
# 2      4                    NaN            NaN  2012-04-23T14:48:07Z  Biking
# 3      5                    NaN            NaN  2012-09-04T23:13:34Z  Biking
# 4      6                    NaN            NaN  2014-06-20T23:24:34Z  Biking
#
#   TotalTimeSeconds DistanceMeters VirtualPartner PlanName PlanType  \
# 0              NaN            NaN            NaN        "      NaN
# 1              NaN            NaN            NaN        "      NaN
# 2              NaN            NaN            NaN        "      NaN
# 3              NaN            NaN            NaN        "      NaN
# 4              NaN            NaN            NaN        "      NaN
#
#   IntervalWorkout Notes    Creator "\n1"  Unnamed: 14  Unnamed: 15  \
# ...

# %%
raw.tail()
# Out:
#                   RecID" MultiSportSessionRecID  NextSportRecID  \
# 15375    CourseLap Table                    NaN             NaN
# 15376        CourseRecID       TotalTimeSeconds  DistanceMeters
# 15377                NaN                    NaN             NaN
# 15378  CoursePoint Table                    NaN             NaN
# 15379        CourseRecID                   Name            Time
#
#            StartTime           Sport     TotalTimeSeconds DistanceMeters  \
# 15375            NaN             NaN                  NaN            NaN
# 15376  BeginLatitude  BeginLongitude  BeginAltitudeMeters    EndLatitude
# 15377            NaN             NaN                  NaN            NaN
# 15378            NaN             NaN                  NaN            NaN
# 15379       Latitude       Longitude       AltitudeMeters      PointType
#
#       VirtualPartner           PlanName             PlanType  \
# 15375            NaN                NaN                  NaN
# ...

# %%
raw[500:550]
# Out:
#     RecID" MultiSportSessionRecID NextSportRecID             StartTime  \
# 500    502                    NaN            NaN  2014-01-15T00:21:30Z
# 501    503                    NaN            NaN  2013-04-08T23:15:25Z
# 502    504                    NaN            NaN  2012-08-29T23:15:01Z
# 503    505                    NaN            NaN  2012-10-02T23:15:47Z
# 504    506                    NaN            NaN  2014-03-14T23:21:10Z
# 505    507                    NaN            NaN  2013-09-18T13:37:20Z
# 506    508                    NaN            NaN  2013-11-17T23:28:38Z
# 507    509                    NaN            NaN  2013-10-25T13:38:07Z
# 508    510                    NaN            NaN  2014-02-11T00:24:06Z
# 509    511                    NaN            NaN  2013-03-11T23:15:42Z
# 510    512                    NaN            NaN  2012-07-18T23:16:11Z
# 511    513                    NaN            NaN  2013-12-25T22:48:24Z
# ...
