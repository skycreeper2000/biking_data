# %%
import collections 
import pandas
from lxml import etree as ET #this was missing from 'python for data analysis' example
from lxml import objectify
import numpy as np

# %%
pandas.__version__
# Out:
# '0.15.2'

# %%
path = "2014.tcx"
parsed = objectify.parse(open(path))
root = parsed.getroot()

# %%
#xml_new = ET.tostring(root, pretty_print=True) # a way to view the file, if you couldn't do it from 'more' or 'vim'

# %%
#links in the file are wrong, current url is: http://developer.garmin.com/schemas/tcx/v2/

# %%
#kids = root.Activities.Activity.Lap.Extensions.getchildren()

# %%
root.Activities.Activity.Lap.descendantpaths()
# Out:
# [u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.TotalTimeSeconds',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.DistanceMeters',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.MaximumSpeed',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.Calories',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.Intensity',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.Cadence',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.TriggerMethod',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.Extensions',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.Extensions.{http://www.garmin.com/xmlschemas/FatCalories/v1}FatCalories',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.Extensions.{http://www.garmin.com/xmlschemas/FatCalories/v1}FatCalories.Value',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.Extensions.{http://www.garmin.com/xmlschemas/ActivityExtension/v2}LX',
#  u'{http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2}Lap.Extensions.{http://www.garmin.com/xmlschemas/ActivityExtension/v2}LX.AvgSpeed']

# %%
#upper_field = ['Id','Lap']
#middle_field = ['TotalTimeSeconds', 'DistanceMeters', 'MaximumSpeed', 'Calories']

#extensions = ['AvgSpeed']

timestamps = []

count = 0 #count laps
StartTime = []
TotalTimeSeconds = [] 
DistanceMeters = []
MaximumSpeed = []
Calories = []

AvgSpeedList = []

for activity in root.Activities.Activity:
    for lap in activity.Lap:
        #print dir(lap)    #to get all the elements
        #print lap.getchildren()
        #print lap.Extensions
        #print child.tag
        #print timestamps
        count +=1
        StartTime.append(lap.values()[0]) 
        TotalTimeSeconds.append(float(lap.TotalTimeSeconds.text))
        DistanceMeters.append(float(lap.DistanceMeters.text))
        MaximumSpeed.append(float(lap.MaximumSpeed.text))
        Calories.append(float(lap.Calories.text))
        
        kids= lap.Extensions.getchildren()
        avgspeed = kids[1].AvgSpeed.pyval #have to do pyval to get rid of nested brackets from xml
        AvgSpeedList.append(avgspeed)

            
        
print count
# Out:
# 523

# %%
root.Activities.Activity.Lap[1].values()
# Out:
# ['2014-02-07T15:47:50Z']

# %%
#check that desired lists are all the same length, prior to joining them 
print len(StartTime), len(TotalTimeSeconds), len(DistanceMeters), len(MaximumSpeed), len(Calories), len(AvgSpeedList)
# Out:
# 523 523 523 523 523 523

# %%
#convert lists to pandas Series and round off to reasonable significant figures
StartTime = pandas.Series(StartTime)
TotalTimeSeconds = pandas.Series(TotalTimeSeconds)
DistanceMeters = pandas.Series(DistanceMeters)
MaximumSpeed = pandas.Series(MaximumSpeed)
Calories = pandas.Series(Calories)
AverageSpeed = pandas.Series(AvgSpeedList)

#get rid of extra decimal places
DistanceMeters = DistanceMeters.round(2)
MaximumSpeed = MaximumSpeed.round(2)
AverageSpeed = AverageSpeed.round(2)

# %%
#join Series as columns in a new dataframe
df = pandas.concat([StartTime, TotalTimeSeconds, DistanceMeters, MaximumSpeed, Calories, AverageSpeed], axis=1)

# %%
#check the dimensions of the resulting dataframe
df.shape
# Out:
# (523, 6)

# %%
#rename the columns to something useful
df.columns = ['StartTime','TotalTimeSeconds', 'DistanceMeters', 'MaximumSpeed', 'Calories', 'AverageSpeed']

# %%
#check how it looks
df.head()
# Out:
#               StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 0  2014-02-07T14:41:03Z            614.76         4822.52         12.43
# 1  2014-02-07T15:47:50Z           1751.72        14645.62         12.12
# 2  2014-10-16T13:37:12Z            629.12         4780.81         12.49
# 3  2014-10-16T14:48:11Z           1594.29        14645.15         14.13
# 4  2014-09-16T23:23:18Z           1629.11        14082.75         12.80
#
#    Calories  AverageSpeed
# 0       275          7.84
# 1       569          8.36
# 2       261          7.60
# 3       595          9.19
# 4       573          8.64

# %%
df.describe()
# Out:
#        TotalTimeSeconds  DistanceMeters  MaximumSpeed     Calories  \
# count        523.000000      523.000000    523.000000   523.000000
# mean        1231.675411     9707.436444     14.713212   410.028681
# std          653.071413     5474.865044     42.978011   214.167919
# min            1.230000        0.000000      1.540000     0.000000
# 25%          664.990000     4777.975000     10.830000   219.500000
# 50%         1469.310000    13054.870000     12.170000   486.000000
# 75%         1670.340000    14336.655000     12.980000   580.500000
# max         6611.030000    40011.900000    731.330000  2014.000000
#
#        AverageSpeed
# count    523.000000
# mean       7.583595
# std        1.739390
# min        0.000000
# 25%        6.010000
# 50%        7.960000
# 75%        8.595000
# max       29.320000

# %%
#have to sort the df by StartTimes before converting to a DateTime Index
sorted_by_date = df.sort_index(by='StartTime')

# %%
sorted_by_date.head()
# Out:
#                 StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 397  2014-01-02T14:44:27Z            615.57         4734.30         12.89
# 398  2014-01-02T15:46:13Z           1742.94        14638.76         11.63
# 12   2014-01-03T00:20:08Z           1670.34        14112.42         13.76
# 13   2014-01-03T01:38:46Z            857.27         4813.75          9.23
# 362  2014-01-03T14:37:08Z            605.17         4735.76         12.94
#
#      Calories  AverageSpeed
# 397       209          7.69
# 398       559          8.40
# 12        553          8.45
# 13        268          5.62
# 362       174          7.83

# %%
#write this out to a separate file for other purposes before converting to use as index
sorted_by_date.to_csv("sorted_by_date_2014.csv")

# %%
#have to convert StartTime to a DateTime Index to do seasonal analysis
sorted_by_date['StartTime'] = sorted_by_date['StartTime'].apply(pandas.to_datetime)

# %%
sorted_by_date.head()
# Out:
#               StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 397 2014-01-02 14:44:27            615.57         4734.30         12.89
# 398 2014-01-02 15:46:13           1742.94        14638.76         11.63
# 12  2014-01-03 00:20:08           1670.34        14112.42         13.76
# 13  2014-01-03 01:38:46            857.27         4813.75          9.23
# 362 2014-01-03 14:37:08            605.17         4735.76         12.94
#
#      Calories  AverageSpeed
# 397       209          7.69
# 398       559          8.40
# 12        553          8.45
# 13        268          5.62
# 362       174          7.83

# %%
#get rid of timestamp here, before you make it the index, as an alternative option for plotting later
daily = sorted_by_date
daily.head()
# Out:
#               StartTime  TotalTimeSeconds  DistanceMeters  MaximumSpeed  \
# 397 2014-01-02 14:44:27            615.57         4734.30         12.89
# 398 2014-01-02 15:46:13           1742.94        14638.76         11.63
# 12  2014-01-03 00:20:08           1670.34        14112.42         13.76
# 13  2014-01-03 01:38:46            857.27         4813.75          9.23
# 362 2014-01-03 14:37:08            605.17         4735.76         12.94
#
#      Calories  AverageSpeed
# 397       209          7.69
# 398       559          8.40
# 12        553          8.45
# 13        268          5.62
# 362       174          7.83

# %%
daily.set_index(['StartTime'], inplace=True)

# %%
daily.head()
# Out:
#                      TotalTimeSeconds  DistanceMeters  MaximumSpeed  Calories  \
# StartTime
# 2014-01-02 14:44:27            615.57         4734.30         12.89       209
# 2014-01-02 15:46:13           1742.94        14638.76         11.63       559
# 2014-01-03 00:20:08           1670.34        14112.42         13.76       553
# 2014-01-03 01:38:46            857.27         4813.75          9.23       268
# 2014-01-03 14:37:08            605.17         4735.76         12.94       174
#
#                      AverageSpeed
# StartTime
# 2014-01-02 14:44:27          7.69
# 2014-01-02 15:46:13          8.40
# 2014-01-03 00:20:08          8.45
# 2014-01-03 01:38:46          5.62
# 2014-01-03 14:37:08          7.83

# %%
days = daily.resample('B') #have to do this while it's a datetime object, before truncating

# %%
days.head()
# Out:
#             TotalTimeSeconds  DistanceMeters  MaximumSpeed    Calories  \
# StartTime
# 2014-01-02       1179.255000     9686.530000     12.260000  384.000000
# 2014-01-03       1219.643333     9529.123333     11.491667  399.666667
# 2014-01-06       1157.545000     9690.615000     12.605000  377.500000
# 2014-01-07       1198.012500     9527.442500     11.667500  397.500000
# 2014-01-08       1248.662500     9596.760000     10.887500  391.750000
#
#             AverageSpeed
# StartTime
# 2014-01-02      8.045000
# 2014-01-03      7.476667
# 2014-01-06      8.185000
# 2014-01-07      7.647500
# 2014-01-08      7.347500

# %%
days.index = days.index.values.astype('M8[D]')

# %%
days.head()
# Out:
#             TotalTimeSeconds  DistanceMeters  MaximumSpeed    Calories  \
# 2014-01-02       1179.255000     9686.530000     12.260000  384.000000
# 2014-01-03       1219.643333     9529.123333     11.491667  399.666667
# 2014-01-06       1157.545000     9690.615000     12.605000  377.500000
# 2014-01-07       1198.012500     9527.442500     11.667500  397.500000
# 2014-01-08       1248.662500     9596.760000     10.887500  391.750000
#
#             AverageSpeed
# 2014-01-02      8.045000
# 2014-01-03      7.476667
# 2014-01-06      8.185000
# 2014-01-07      7.647500
# 2014-01-08      7.347500

# %%
days.to_csv("days_only_2014.csv")

# %%
#use built-in shortcut to group by quarters (each 3-month span roughly 1 season - can shift this using offsets)
means = stamped.resample('Q')

# %%
rounder = np.round(means, 2)
rounder.to_csv("quarterly.csv")

# %%
#ok we know this is probably not too meaningful because some of these distributions are not gaussian...
